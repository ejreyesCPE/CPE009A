# %% [markdown]
# <a href="https://colab.research.google.com/github/ejreyesCPE/CPE009A/blob/main/Hands_on_Activity_1_1_Literals%2C_Operators%2C_and_Variables(REYES).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Assigning variables of different data types in Python**

# %%
# 1. In an empty cell, declare a variable value and assign it the value of 5 then display its value using print().
value = 5
print(value)
# Out:
# 5

# %%
# 2. Create a new cell and type the command: type(value) then run the cell. The output should be like the image below.
type(value)
# Out:
# int

# %%
# 3. In a new cell, use the same variable value and assign it the value of 5.0 then print the value.
value = 5.0
print(value)
# Out:
# 5.0

# %%
# 4. Repeat step 2.
type(value)
# Out:
# float

# %%
# 5. REpeat these steps for the following values:
value = 2+3j
print(value)
print(type(value))
print("\n")

value = 'Hello World'
print(value)
print(type(value))
print("\n")

value = "Hello World"
print(value)
print(type(value))
print("\n")

value = True
print(value)
print(type(value))
print("\n")

value = False
print(value)
print(type(value))
print("\n")

value = [1,2,3,4,5]
print(value)
print(type(value))
print("\n")

value = (1,2,3,4,5)
print(value)
print(type(value))
print("\n")

value = {'name': 'Eli'}
print(value)
print(type(value))
print("\n")

value = None
print(value)
print(type(value))
print("\n")
# Out:
# (2+3j)
# <class 'complex'>
#
#
# Hello World
# <class 'str'>
#
#
# Hello World
# <class 'str'>
#
#
# True
# <class 'bool'>
#
#
# False
# <class 'bool'>
#
#
# [1, 2, 3, 4, 5]
# <class 'list'>
#
#
# (1, 2, 3, 4, 5)
# <class 'tuple'>
#
#
# {'name': 'Eli'}
# <class 'dict'>
#
#
# None
# <class 'NoneType'>

# %%
# 6. Re-assign the value variable to be equal to 5.
value = 5

# %%
# 7. Declare a new variable named value2 to be equal to -6
value2 = -6

# %% [markdown]
# **Performing Operations with Python**

# %%
# 1. Using value and value2. Type the command: print(value+value2)
print(value+value2)
# Out:
# -1

# %%
# 2. Repeat step 1 for the following values of value and value2.
value = 5.0
value2 = 6
print(value+value2)
print("\n")

value = -5
value2 = 6.1
print(value+value2)
print("\n")

value = "Hello "
value2 = 'world'
print(value+value2)
print("\n")

value = [1,2,3]
value2 = [4,5,6]
print(value+value2)
print("\n")

value = (1,2,3)
value2 = (4,5,6)
print(value+value2)
print("\n")

value = {"name":"Royce"}
value2 = {"age":2}
print(value | value2)
print("\n")
# Out:
# 11.0
#
#
# 1.0999999999999996
#
#
# Hello world
#
#
# [1, 2, 3, 4, 5, 6]
#
#
# (1, 2, 3, 4, 5, 6)
#
#
# {'name': 'Royce', 'age': 2}

# %%
# 3. Using value, value2 = 30, 4.

value = 30
value2 = 4

print(value*value2)
print(value2**2)
print(value2**3)
print(value*value2+value2**2+1)
print(value/value2)
print(value%value2)
# Out:
# 120
# 16
# 64
# 137
# 7.5
# 2

# %% [markdown]
# **Receiving Input Data Using Python**

# %%
input("Message Name")
# Out:
# Message Namehi
# 'hi'

# %%
name = input("Enter your name: ")
# Out:
# Enter your name: Eli

# %% [markdown]
# **Assigning Input Data to a Variable**

# %%
# 1. Declare a new variable named name and assign it the value input(“Enter your name”)
name = input("Enter your name: ")

# 2. Create another variable named weight and assign it the value input(“Enter your weight(kg): “)
weight = float(input("Enter your weight(kg): "))
# 3. Create another variable named height and assign it the value input(“Enter your meters(m): “)
height = float(input("Enter your meters(m): "))

# 4. Declare another variable called bmi and assign it the formula.
bmi = weight / (height ** 2)

# 5. Address the errors displayed step#4. You can accomplish this by converting the String input to another data type.

# 6. Print the persons’s name, weight, height, and bmi.
print("\n")
print(f"Name: {name}")
print(f"Weight: {weight}")
print(f"Height: {height}")
# Out:
# Enter your name: John Ray
# Enter your weight(kg): 60
# Enter your meters(m): 1.6764
#
#
# Name: John Ray
# Weight: 60.0
# Height: 1.6764

# %% [markdown]
# **Supplementary Activity**

# %%
# 1. Write the Python equivalent code of the following C code.

base = float(input("Enter the base of the triangle: "))
height = float(input("Enter the height of the triangle: "))
area = (1/2)*base*height
print("The area of the triangle is: ", area)
# Out:
# Enter the base of the triangle: 6
# Enter the height of the triangle: 3
# The area of the triangle is:  9.0

# %%
# 2. Write a program that would convert Celsius to Fahrenheit given the formula: F = (C × 9/5) + 32

Cel = float(input("Enter Celsius: "))
fah = (Cel * 9/5) + 32
print(f"{Cel} Celsius is equal to {fah} Fahrenheit")
# Out:
# Enter Celsius: 37
# 37.0 Celsius is equal to 98.6 Fahrenheit

# %%
# 3. Write a program that can determine the distance between two points given the coordinates using the formula.
x1 = float(input("Enter x1: "))
y1 = float(input("Enter y1: "))
x2 = float(input("Enter x2: "))
y2 = float(input("Enter y2: "))

d = ((x2 - x1)**2 + (y2 - y1)**2)**0.5

print("\n")
print("The answer is:", d)
# Out:
# Enter x1: 2
# Enter y1: 2
# Enter x2: -3
# Enter y2: 3
#
#
# The answer is: 5.0990195135927845
